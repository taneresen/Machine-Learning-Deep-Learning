# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.catplot(x= "sepal_width", y = "species", data=iris, jitter = False)

# %%
sns.catplot(x= "sepal_width", y = "species", data=iris, kind = "swarm")

# %%
sns.jointplot("sepal_length" , "petal_width", kind="scatter", data= iris)
# Out:
# C:\Users\taner\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(iris, hue='species', height=2.5);

# %%
sns.pairplot(iris, hue='species', height=2.5, vars= ["petal_length" , "petal_width"]);

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
X_train,X_validation,y_train, y_validation=train_test_split(iris.iloc[:, 0:4],iris.iloc[:,4],test_size=0.3)

# %%
y_train.head()
# Out:
# 6          setosa
# 55     versicolor
# 19         setosa
# 60     versicolor
# 119     virginica
# Name: species, dtype: object

# %%
clf = svm.LinearSVC()
clf.fit(X_train,y_train)
# Out:
# C:\Users\taner\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# LinearSVC()

# %%
pred = clf.predict(X_validation)
conf_matrix = confusion_matrix(y_validation, pred)
conf_matrix
# Out:
# array([[13,  0,  0],
#        [ 0, 12,  2],
#        [ 0,  0, 18]], dtype=int64)

# %%
species = iris.species.unique()
sns.heatmap(conf_matrix, xticklabels=species,yticklabels=species, annot=True, cmap = "summer")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(iris.corr())
# Out:
# <AxesSubplot:>
